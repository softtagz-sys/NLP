# %%
# Import necessary libraries
from spacy_utils import *
# Out:
# C:\pythonenvironments\DataAndAi\Lib\site-packages\spacy\util.py:910: UserWarning: [W095] Model 'en_core_web_sm' (3.7.1) was trained with spaCy v3.7.2 and may not be 100% compatible with the current version (3.8.2). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
# Create Spacy document
doc_moby_dick = create_doc('../text_data/mobydick_extract.txt')

# %%
# Get tokenization, POS, and grammatical structure
print("Tokenization, POS, and Grammatical Structure for mobydick_extract.txt.txt:")
tokenization_pos_df = get_tokenization_and_pos(doc_moby_dick)
tokenization_pos_df
# Out:
# Tokenization, POS, and Grammatical Structure for mobydick_extract.txt:
#                                        SENTENCE          WORD    POS    DEP  \
# 0    The vast tackles have now done their duty.           NaN    NaN    NaN
# 1                                           NaN           The    DET    det
# 2                                           NaN          vast    ADJ   amod
# 3                                           NaN       tackles   NOUN  nsubj
# 4                                           NaN          have    AUX    aux
# ..                                          ...           ...    ...    ...
# 193                                         NaN            in    ADP   prep
# 194                                         NaN      infinite    ADJ   amod
# 195                                         NaN            \n  SPACE    dep
# 196                                         NaN  perspectives   NOUN   pobj
# ...

# %%
# Get named entities
print("\nNamed Entities for mobydick_extract.txt.txt:")
named_entities_df = get_named_entities(doc_moby_dick)
named_entities_df
# Out:
# Named Entities for mobydick_extract.txt:
#             Entity Label
# 0  hours and hours  TIME

# %%
# Explain POS and dependency tags
print("\nExplanation of POS and Dependency Tags for mobydick_extract.txt.txt:")
tags_explanation_df = explain_tags(doc_moby_dick)
tags_explanation_df
# Out:
# Explanation of POS and Dependency Tags for mobydick_extract.txt:
#             Token    POS POS Explanation Dependency  Dependency Explanation
# 0             The    DET      determiner        det              determiner
# 1            vast    ADJ       adjective       amod     adjectival modifier
# 2         tackles   NOUN            noun      nsubj         nominal subject
# 3            have    AUX       auxiliary        aux               auxiliary
# 4             now    ADV          adverb     advmod      adverbial modifier
# ..            ...    ...             ...        ...                     ...
# 186            in    ADP      adposition       prep  prepositional modifier
# 187      infinite    ADJ       adjective       amod     adjectival modifier
# 188            \n  SPACE           space        dep  unclassified dependent
# 189  perspectives   NOUN            noun       pobj   object of preposition
# ...
